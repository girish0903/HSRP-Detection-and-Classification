# %%
import tensorflow as tf
from model import create_model

# Function to load the entire model
def load_model(model_path):
    return tf.keras.models.load_model(model_path)

# Function to load the test data
def load_test_data(data_dir):
    test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
        data_dir,
        image_size=(128, 128),  # Adjust image size based on your dataset
        batch_size=32,
        shuffle=False  # Disable shuffling for evaluation
    )
    return test_dataset

# Path to the saved model
model_path = "model_inception.h5"

# Load the entire model
model = load_model(model_path)

# Compile the model with the same configuration as during training
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Load the test data (ensure you use the correct path to your dataset)
test_dir = "Classification.v1i.folder (1)/test"  # Specify the correct path to your test dataset directory
test_dataset = load_test_data(test_dir)

# Evaluate the model
loss, accuracy = model.evaluate(test_dataset)
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")

# Optionally, make predictions with the model
predictions = model.predict(test_dataset)
# print(predictions)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Found 61 files belonging to 2 classes.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 280ms/step - accuracy: 0.2514 - loss: 878.0861
# Test Loss:0.1658456
# Test Accuracy: 0.9112568
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step

# %%
import tensorflow as tf
from PIL import Image
import numpy as np
from IPython.display import display

# Function to load the entire model
def load_model(model_path):
    return tf.keras.models.load_model(model_path)

# Path to the saved model
model_path = "model_inception.h5"

# Load the entire model
model = load_model(model_path)

# Compile the model with the same configuration as during training
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Function to preprocess the uploaded image
def preprocess_image(image):
    image = tf.image.resize(image, (128, 128))
    image = tf.cast(image, tf.float32) / 255.0  # Normalize the pixel values
    return image

# Function to make predictions on the uploaded image
# Function to make predictions on the uploaded image
def predict_image(image_path, model):
    img = Image.open(image_path)
    img.thumbnail((256, 256))  # Resize the image to a maximum of 256x256
    display(img)
    img = preprocess_image(img)
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    predictions = model.predict(img)
    predicted_class = np.argmax(predictions, axis=1)[0]
    if predicted_class == 0:
        print("Predicted Class: HSRP")
    else:
        print("Predicted Class: NON HSRP")



# Path to the uploaded image
image_path = "Classification.v1i.folder (1)/valid/HSRP/IMG_6058_JPG_cropped_jpg.rf.377ab2608ca17fe0d8c291107ca4c009.jpg"  # Specify the correct path to your uploaded image

# Make predictions on the uploaded image
predicted_class = predict_image(image_path, model)
# print("Predicted Class:", predicted_class)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Predicted Class: HSRP

# %%
import tensorflow as tf
from PIL import Image
import numpy as np
from IPython.display import display

# Function to load the entire model
def load_model(model_path):
    return tf.keras.models.load_model(model_path)

# Path to the saved model
model_path = "model_inception.h5"

# Load the entire model
model = load_model(model_path)

# Compile the model with the same configuration as during training
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Function to preprocess the uploaded image
def preprocess_image(image):
    image = tf.image.resize(image, (128, 128))
    image = tf.cast(image, tf.float32) / 255.0  # Normalize the pixel values
    return image

# Function to make predictions on the uploaded image
# Function to make predictions on the uploaded image
def predict_image(image_path, model):
    img = Image.open(image_path)
    img.thumbnail((256, 256))  # Resize the image to a maximum of 256x256
    display(img)
    img = preprocess_image(img)
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    predictions = model.predict(img)
    predicted_class = np.argmax(predictions, axis=1)[0]
    if predicted_class == 0:
        print("Predicted Class: HSRP")
    else:
        print("Predicted Class: NON HSRP")



# Path to the uploaded image
image_path = "Classification.v1i.folder (1)/valid/NON HSRP/IMG_5644_JPG_cropped_jpg.rf.836ca08ba8195c4f442a5c3fb22222bf.jpg"  # Specify the correct path to your uploaded image

# Make predictions on the uploaded image
predicted_class = predict_image(image_path, model)
# print("Predicted Class:", predicted_class)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Predicted Class: NON HSRP
